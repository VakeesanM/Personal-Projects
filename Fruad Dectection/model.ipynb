# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df["type"].value_counts().plot(kind='bar')
plt.show()

# %%
fraud_group_rate = df.groupby("type")["isFraud"].mean().sort_values(ascending=False)
fraud_group_rate.plot(kind = "bar", title="Fraud by Type", color='red')
plt.show()

# %%
df["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df["amount"]), bins=100, kde=True)
plt.show()

# %%
sns.boxplot(data=df[df["amount"] < 50000], x='isFraud', y="amount")
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df['balancediffOrig'] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df['balanceDiffDest'] = df["newbalanceDest"] - df['oldbalanceDest']

# %%
(df['balancediffOrig'] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df['balanceDiffDest'] < 0).sum()
# Out:
# np.int64(1238864)

# %%
df = df.drop(columns=["step"])

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balancediffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
Fraud_recievers = df[df["isFraud"]==1]['nameOrig'].value_counts().head(10)
Fraud_recievers
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
df[df["isFraud"]==1]['type'].value_counts()
#Only 2 types of transcations have a case of fruad, so all other types can  be dropped.
# Out:
# type
# CASH_OUT    4116
# TRANSFER    4097
# Name: count, dtype: int64

# %%
fraud_types = df[df['type'].isin(["TRANSFER","CASH_OUT"])]
fraud_types.shape
# Out:
# (2770409, 12)

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balancediffOrig', 'balanceDiffDest'],
#       dtype='object')

# %%
corr = df[["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "isFraud"]].corr()
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt='.2f')
plt.show()

# %%
zero_balance = df[
    (df["oldbalanceOrg"] > 0 ) & (df["newbalanceOrig"] == 0 ) & df['type'].isin(["TRANSFER","CASH_OUT"])]

zero_balance.shape
# Out:
# (1188074, 12)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balancediffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
df_model = df.drop(["nameOrig", "nameDest", "isFlaggedFraud"], axis=1)

# %%
df_model
# Out:
#              type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         PAYMENT     9839.64      170136.00       160296.36            0.00
# 1         PAYMENT     1864.28       21249.00        19384.72            0.00
# 2        TRANSFER      181.00         181.00            0.00            0.00
# 3        CASH_OUT      181.00         181.00            0.00        21182.00
# 4         PAYMENT    11668.14       41554.00        29885.86            0.00
# ...           ...         ...            ...             ...             ...
# 6362615  CASH_OUT   339682.13      339682.13            0.00            0.00
# 6362616  TRANSFER  6311409.28     6311409.28            0.00            0.00
# 6362617  CASH_OUT  6311409.28     6311409.28            0.00        68488.84
# 6362618  TRANSFER   850002.52      850002.52            0.00            0.00
# 6362619  CASH_OUT   850002.52      850002.52            0.00      6510099.11
#
# ...

# %%
y = df['isFraud']
X = df.drop("isFraud", axis= 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
df_model.columns
# Out:
# Index(['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
#        'newbalanceDest', 'isFraud', 'balancediffOrig', 'balanceDiffDest'],
#       dtype='object')

# %%
numeric = ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest','newbalanceDest']
categorical = ['type']

# %%
preprcoesser = ColumnTransformer(
    transformers= [
        ('num', StandardScaler(), numeric),
        ('cat', OneHotEncoder(drop='first'), categorical)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([
    ('prep', preprcoesser),
    ("clf", LogisticRegression(class_weight='balanced', max_iter=1000))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred  = pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.95      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.95      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap="coolwarm", fmt='.2f')
plt.show()

# %%
print(f"Accuracy: {round(pipeline.score(X_test, y_test)*100, 2)}%")
# Out:
# Accuracy: 94.59%

# %%
import joblib

# %%
joblib.dump(pipeline, 'fruad_decection_model_pipleine.pkl')
# Out:
# ['fruad_decection_model_pipleine.pkl']
